# %%
### clean data

import pandas as pd
import sys
from pathlib import Path
data = pd.read_parquet("../data/raw/v2025.12.08.1716/broadband_processed_data.parquet").drop_duplicates()

# %%
data_cleaned = data.drop(columns=["description", 'payment_method', 'transaction_type'])
cleaned = data.loc[:, ['primary_merchant', 'transaction_classification_0', 'transaction_classification_1', 'customer_id', 'account_id', 'date', 'amount', 'credit_debit', 'timestamp']]
cleaned = cleaned.loc[cleaned['primary_merchant'] != '']
classification_stats = cleaned.groupby('transaction_classification_0')['amount'].agg(
        avg_amount_by_classification='mean',
        total_txn_by_classification='count'
    )
cleaned = cleaned.merge(classification_stats, on='transaction_classification_0', how='left')
cleaned
cleaned.to_parquet("../data/cleaned/columns_selected.parquet", index=False)

# %%
cleaned
# Out:
#                primary_merchant transaction_classification_0  \
# 0                        PAYPAL           Financial Services
# 1                         BANDM                     Shopping
# 2                      BUTCHERS                Food & Dining
# 3                          SPAR                    Groceries
# 4                   VANQUISBANK            Personal Services
# ...                         ...                          ...
# 838750               TESCO_BANK                Bank products
# 838751  LEGAL_GENERAL_INSURANCE                    Insurance
# 838752                     HSBC                Bank products
# 838753                PARENTPAY                    Education
# 838754             VIRGIN MEDIA           Telecommunications
#
#        transaction_classification_1                           customer_id  \
# 0                Financial Services  01fa4fcb-5cd0-4484-aea2-be6850ad56bd
# 1                           General  01fa4fcb-5cd0-4484-aea2-be6850ad56bd
# 2                       Restaurants  01fa4fcb-5cd0-4484-aea2-be6850ad56bd
# 3                         Groceries  01fa4fcb-5cd0-4484-aea2-be6850ad56bd
# 4                     Bank products  01fa4fcb-5cd0-4484-aea2-be6850ad56bd
# ...                             ...                                   ...
# 838750                Bank products  h0ce51ee-8e08-4ddf-8ada-ad8b5f7f9c2e
# 838751                    Insurance  h0ce51ee-8e08-4ddf-8ada-ad8b5f7f9c2e
# 838752                Bank products  h0ce51ee-8e08-4ddf-8ada-ad8b5f7f9c2e
# 838753                      General  h0ce51ee-8e08-4ddf-8ada-ad8b5f7f9c2e
# 838754           Mobile & Broadband  h0ce51ee-8e08-4ddf-8ada-ad8b5f7f9c2e
#
#                               account_id        date  amount credit_debit  \
# 0       3ba11ff825adcc9ad5f5f2e76b1a549e  2021-03-30   35.94        DEBIT
# 1       3ba11ff825adcc9ad5f5f2e76b1a549e  2021-03-30   65.27        DEBIT
# 2       3ba11ff825adcc9ad5f5f2e76b1a549e  2021-03-30   14.34        DEBIT
# 3       3ba11ff825adcc9ad5f5f2e76b1a549e  2021-03-30   35.60        DEBIT
# 4       3ba11ff825adcc9ad5f5f2e76b1a549e  2021-03-30   12.24        DEBIT
# ...                                  ...         ...     ...          ...
# 838750  c03da4bd089290412656970100b56258  2021-11-15   25.00        DEBIT
# 838751  c03da4bd089290412656970100b56258  2021-11-15   25.61        DEBIT
# 838752  c03da4bd089290412656970100b56258  2021-11-16  500.00        DEBIT
# 838753  c03da4bd089290412656970100b56258  2021-11-17    2.00        DEBIT
# 838754  c03da4bd089290412656970100b56258  2021-11-17   26.00        DEBIT
#
#                               timestamp  avg_amount_by_classification  \
# 0      2021-03-30 04:30:50.770000+00:00                    104.679220
# 1      2021-03-30 04:30:50.784000+00:00                     40.992022
# 2      2021-03-30 04:30:50.791000+00:00                     47.224206
# 3      2021-03-30 04:30:50.793000+00:00                     24.039842
# 4      2021-03-30 04:30:50.799000+00:00                     50.935904
# ...                                 ...                           ...
# 838750        2021-11-15 00:00:00+00:00                    335.447892
# 838751        2021-11-15 00:00:00+00:00                     56.738931
# 838752        2021-11-16 00:00:00+00:00                    335.447892
# 838753        2021-11-17 00:00:00+00:00                    224.260323
# 838754        2021-11-17 00:00:00+00:00                     58.451092
#
#         total_txn_by_classification
# 0                            143654
# 1                            125894
# 2                             87781
# 3                             91087
# 4                             27846
# ...                             ...
# 838750                        42087
# 838751                          552
# 838752                        42087
# 838753                         2325
# 838754                        27233
#
# [838755 rows x 11 columns]

# %%
pd.read_parquet("/Users/dm1223/Desktop/Barclays-compass/data/cleaned/columns_selected.parquet")
# Out:
#                primary_merchant transaction_classification_0  \
# 0                        PAYPAL           Financial Services
# 1                         BANDM                     Shopping
# 2                      BUTCHERS                Food & Dining
# 3                          SPAR                    Groceries
# 4                   VANQUISBANK            Personal Services
# ...                         ...                          ...
# 838750               TESCO_BANK                Bank products
# 838751  LEGAL_GENERAL_INSURANCE                    Insurance
# 838752                     HSBC                Bank products
# 838753                PARENTPAY                    Education
# 838754             VIRGIN MEDIA           Telecommunications
#
#        transaction_classification_1                           customer_id  \
# 0                Financial Services  01fa4fcb-5cd0-4484-aea2-be6850ad56bd
# 1                           General  01fa4fcb-5cd0-4484-aea2-be6850ad56bd
# 2                       Restaurants  01fa4fcb-5cd0-4484-aea2-be6850ad56bd
# 3                         Groceries  01fa4fcb-5cd0-4484-aea2-be6850ad56bd
# 4                     Bank products  01fa4fcb-5cd0-4484-aea2-be6850ad56bd
# ...                             ...                                   ...
# 838750                Bank products  h0ce51ee-8e08-4ddf-8ada-ad8b5f7f9c2e
# 838751                    Insurance  h0ce51ee-8e08-4ddf-8ada-ad8b5f7f9c2e
# 838752                Bank products  h0ce51ee-8e08-4ddf-8ada-ad8b5f7f9c2e
# 838753                      General  h0ce51ee-8e08-4ddf-8ada-ad8b5f7f9c2e
# 838754           Mobile & Broadband  h0ce51ee-8e08-4ddf-8ada-ad8b5f7f9c2e
#
#                               account_id        date  amount credit_debit  \
# 0       3ba11ff825adcc9ad5f5f2e76b1a549e  2021-03-30   35.94        DEBIT
# 1       3ba11ff825adcc9ad5f5f2e76b1a549e  2021-03-30   65.27        DEBIT
# 2       3ba11ff825adcc9ad5f5f2e76b1a549e  2021-03-30   14.34        DEBIT
# 3       3ba11ff825adcc9ad5f5f2e76b1a549e  2021-03-30   35.60        DEBIT
# 4       3ba11ff825adcc9ad5f5f2e76b1a549e  2021-03-30   12.24        DEBIT
# ...                                  ...         ...     ...          ...
# 838750  c03da4bd089290412656970100b56258  2021-11-15   25.00        DEBIT
# 838751  c03da4bd089290412656970100b56258  2021-11-15   25.61        DEBIT
# 838752  c03da4bd089290412656970100b56258  2021-11-16  500.00        DEBIT
# 838753  c03da4bd089290412656970100b56258  2021-11-17    2.00        DEBIT
# 838754  c03da4bd089290412656970100b56258  2021-11-17   26.00        DEBIT
#
#                               timestamp  avg_amount_by_classification  \
# 0      2021-03-30 04:30:50.770000+00:00                    104.679220
# 1      2021-03-30 04:30:50.784000+00:00                     40.992022
# 2      2021-03-30 04:30:50.791000+00:00                     47.224206
# 3      2021-03-30 04:30:50.793000+00:00                     24.039842
# 4      2021-03-30 04:30:50.799000+00:00                     50.935904
# ...                                 ...                           ...
# 838750        2021-11-15 00:00:00+00:00                    335.447892
# 838751        2021-11-15 00:00:00+00:00                     56.738931
# 838752        2021-11-16 00:00:00+00:00                    335.447892
# 838753        2021-11-17 00:00:00+00:00                    224.260323
# 838754        2021-11-17 00:00:00+00:00                     58.451092
#
#         total_txn_by_classification
# 0                            143654
# 1                            125894
# 2                             87781
# 3                             91087
# 4                             27846
# ...                             ...
# 838750                        42087
# 838751                          552
# 838752                        42087
# 838753                         2325
# 838754                        27233
#
# [838755 rows x 11 columns]

# %%
# Merchants with empty/missing classifications
cleaned[
    (cleaned['transaction_classification_0'].isna() | (cleaned['transaction_classification_0'] == '')) |
    (cleaned['transaction_classification_1'].isna() | (cleaned['transaction_classification_1'] == ''))
]['primary_merchant'].value_counts()
# Out:
# primary_merchant
# PRET    178
# Name: count, dtype: int64
